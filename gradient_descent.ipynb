# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y):
    learning_rate=0.01
    it=100
    n=len(x)
    m_curr=b_curr=0
    for i in range (it):
        y_pred=m_curr*x+b_curr
        cost=(1/n)*sum(val**2 for val in (y-y_pred))
        md=-(2/n)*sum(x*(y-y_pred))
        bd=-(2/n)*sum((y-y_pred))
        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        plt.plot(x,y_pred,color='green')
        print("m={},b={},cost={},iterations={}".format(m_curr,b_curr,cost,i))

# %%
x=np.array([1,2,3,4])
y=np.array([15,16,17,18])
gradient_descent(x,y)
# Out:
# m=0.85,b=0.33,cost=273.5,iterations=0
# m=1.556,b=0.6109,cost=197.29015,iterations=1
# m=2.142055,b=0.8508819999999999,cost=144.36482081,iterations=2
# m=2.62820265,b=1.05676161,cost=107.5963965631615,iterations=3
# m=3.031134172,b=1.2342162452999998,cost=82.03917381047378,iterations=4
# m=3.3647532339349997,b=1.3879752117939999,cost=64.2614319740902,iterations=5
# m=3.6406414882550497,b=1.5219780458613699,cost=51.881971166975305,iterations=6
# m=3.8684463627237236,b=1.63950641053139,cost=43.248525591890385,iterations=7
# m=4.056204087788595,b=1.743293964184576,cost=37.21462140306113,iterations=8
# m=4.210608776411077,b=1.8356178805114547,cost=32.98474309760092,iterations=9
# m=4.337236565923843,b=1.9183750840806717,cost=30.00689775045187,iterations=10
# m=4.440732326831233,b=1.993145754102866,cost=27.898067610093666,iterations=11
# m=4.524965190101405,b=2.061246222679247,cost=26.392483231933493,iterations=12
# m=4.593158100452231,b=2.123773038720592,cost=25.305731299953727,iterations=13
# m=4.647995733448367,b=2.1816396729235685,cost=24.509849803509614,iterations=14
# m=4.691714389784933,b=2.2356070927926788,cost=23.91604710739396,iterations=15
# m=4.72617687667756,b=2.2863092314475786,cost=23.46271108013313,iterations=16
# m=4.7529348836035465,b=2.334274202984749,cost=23.107088881762092,iterations=17
# m=4.773280940913777,b=2.379941974744877,cost=22.819513744548246,iterations=18
# m=4.7882917010394666,b=2.4236790882042905,cost=22.579399058232994,iterations=19
# m=4.798863991473332,b=2.465790921388231,cost=22.372458750485777,iterations=20
# m=4.805744846682921,b=2.5065319033868,cost=22.18877856766013,iterations=21
# m=4.809556524511143,b=2.5461140229849177,cost=22.0214777772663,iterations=22
# m=4.810817344685225,b=2.584713916299662,cost=21.865780551580908,iterations=23
# m=4.8099590471674585,b=2.6224787707394075,cost=21.718371620330103,iterations=24
# m=4.8073412515553695,b=2.6595312429662465,cost=21.576949171668133,iterations=25
# m=4.803263501673752,b=2.6959735555291533,cost=21.43991461957546,iterations=26
# m=4.797975298646231,b=2.7318909093348824,cost=21.306157339969463,iterations=27
# m=4.791684458382552,b=2.767354326215873,cost=21.17490530359602,iterations=28
# m=4.7845640733143755,b=2.802423016772428,cost=21.045621433303246,iterations=29
# m=4.776758311478598,b=2.837146352771261,cost=20.917931688496942,iterations=30
# m=4.768387247118245,b=2.8715655101419055,cost=20.79157516441638,iterations=31
# m=4.759550884543413,b=2.905714837583155,cost=20.666369467028495,iterations=32
# m=4.750332509982743,b=2.9396229966043212,cost=20.542186687350693,iterations=33
# m=4.740801483655116,b=2.9733139111730975,cost=20.418936730493304,iterations=34
# m=4.731015565548194,b=3.0068075587668797,cost=20.296555747986584,iterations=35
# m=4.7210228527776215,b=3.0401206293141323,cost=20.174998111169227,iterations=36
# m=4.710863393395272,b=3.0732670740889687,cost=20.05423084164481,iterations=37
# m=4.700570530681532,b=3.106258562937426,cost=19.934229746645997,iterations=38
# m=4.6901720229324315,b=3.139104865144601,cost=19.814976737398403,iterations=39
# m=4.679690976235337,b=3.1718141666950874,cost=19.696457968343175,iterations=40
# m=4.669146621465282,b=3.204393334549419,cost=19.578662545936456,iterations=41
# m=4.6585549615180195,b=3.2368481367851665,cost=19.461581632666324,iterations=42
# m=4.647929310451058,b=3.269183425973562,cost=19.345207825303095,iterations=43
# m=4.637280742584721,b=3.301403291931538,cost=19.229534723434742,iterations=44
# m=4.626618466600436,b=3.3335111889636715,cost=19.114556630037242,iterations=45
# m=4.615950137162187,b=3.3655100418543764,cost=19.000268343661535,iterations=46
# m=4.60528211449514,b=3.3974023341591795,cost=18.886665014191564,iterations=47
# m=4.594619680612911,b=3.4291901817512387,cost=18.773742042713177,iterations=48
# m=4.583967219433412,b=3.4608753940855683,cost=18.661495011990976,iterations=49
# m=4.573328366814122,b=3.4924595252321864,cost=18.5499196381835,iterations=50
# m=4.562706135530394,b=3.5239439163868367,cost=18.439011737295633,iterations=51
# m=4.5521030193814935,b=3.5553297312825802,cost=18.32876720185709,iterations=52
# m=4.54152107991014,b=3.586617985687854,cost=18.21918198469673,iterations=53
# m=4.530962018639227,b=3.6178095719785897,cost=18.110252087640923,iterations=54
# m=4.520427237244413,b=3.6489052796070567,cost=18.001973553628737,iterations=55
# m=4.509917887677398,b=3.679905812152695,cost=17.894342461198352,iterations=56
# m=4.4994349139181535,b=3.710811801525771,cost=17.78735492061896,iterations=57
# m=4.488979086754142,b=3.741623819799348,cost=17.68100707116479,iterations=58
# m=4.478551032751054,b=3.772342389065654,cost=17.5752950791818,iterations=59
# m=4.468151258385113,b=3.8029679896467883,cost=17.4702151367047,iterations=60
# m=4.457780170145007,b=3.833501066934597,cost=17.365763460456034,iterations=61
# m=4.447438091276526,b=3.8639420370886546,cost=17.26193629111063,iterations=62
# m=4.437125275730614,b=3.894291291783055,cost=17.158729892744418,iterations=63
# m=4.42684191978187,b=3.924549202160863,cost=17.0561405524115,iterations=64
# m=4.416588171706546,b=3.954716122128552,cost=16.954164579810282,iterations=65
# m=4.406364139844136,b=3.9847923911006538,cost=16.852798307011856,iterations=66
# m=4.396169899312483,b=4.014778336286434,cost=16.75203808823162,iterations=67
# m=4.386005497601289,b=4.044674274595081,cost=16.651880299631298,iterations=68
# m=4.375870959231341,b=4.074480514223115,cost=16.55232133914214,iterations=69
# m=4.365766289635484,b=4.104197355977086,cost=16.453357626303248,iterations=70
# m=4.355691478391307,b=4.13382509437577,cost=16.354985602110418,iterations=71
# m=4.345646501913823,b=4.163364018568689,cost=16.257201728872623,iterations=72
# m=4.335631325698315,b=4.192814413101624,cost=16.160002490074078,iterations=73
# m=4.325645906188487,b=4.222176558554676,cost=16.0633843902403,iterations=74
# m=4.31569019233248,b=4.251450732074159,cost=15.96734395480717,iterations=75
# m=4.3057641268789,b=4.280637207816052,cost=15.871877729992491,iterations=76
# m=4.295867647456262,b=4.309736257315786,cost=15.77698228266919,iterations=77
# m=4.2860006874720336,b=4.338748149796657,cost=15.682654200240165,iterations=78
# m=4.276163176861395,b=4.3676731524271215,cost=15.588890090514397,iterations=79
# m=4.266355042710829,b=4.396511530535509,cost=15.495686581584042,iterations=80
# m=4.25657620977743,b=4.425263547789258,cost=15.403040321702687,iterations=81
# m=4.246826600921352,b=4.453929466344601,cost=15.310947979164357,iterations=82
# m=4.237106137465919,b=4.482509546971641,cost=15.219406242183446,iterations=83
# m=4.2274147394974495,b=4.511004049158912,cost=15.128411818775419,iterations=84
# m=4.217752326114886,b=4.539413231200862,cost=15.037961436638275,iterations=85
# m=4.208118815637611,b=4.5677373502711,cost=14.948051843034815,iterations=86
# m=4.198514125778414,b=4.595976662483798,cost=14.858679804675592,iterations=87
# m=4.188938173787462,b=4.624131422945201,cost=14.76984210760256,iterations=88
# m=4.179390876572083,b=4.652201885796924,cost=14.681535557073524,iterations=89
# m=4.169872150796424,b=4.680188304252381,cost=14.593756977447164,iterations=90
# m=4.160381912964342,b=4.708090930627512,cost=14.506503212068854,iterations=91
# m=4.150920079488315,b=4.735910016366745,cost=14.419771123157139,iterations=92
# m=4.14148656674673,b=4.763645812064994,cost=14.333557591690877,iterations=93
# m=4.13208129113147,b=4.791298567486358,cost=14.24785951729708,iterations=94
# m=4.122704169087432,b=4.8188685315800575,cost=14.162673818139398,iterations=95
# m=4.113355117145314,b=4.8463559524940845,cost=14.077997430807295,iterations=96
# m=4.104034051948813,b=4.873761077586937,cost=13.993827310205894,iterations=97
# m=4.094740890277144,b=4.901084153437758,cost=13.910160429446453,iterations=98
# m=4.085475549063685,b=4.928325425855145,cost=13.826993779737524,iterations=99

# %%
cd
# Out:
# /home/rupam

# %%
cd Desktop
# Out:
# /home/rupam/Desktop

# %%
df=pd.read_csv('test_scores.csv')

# %%
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
def gradient_descent(x,y):
    learning_rate=0.0002
    it=1000000
    n=len(x)
    m_curr=b_curr=0
    for i in range (it):
        y_pred=m_curr*x+b_curr
        cost=(1/n)*sum(val**2 for val in (y-y_pred))
        md=-(2/n)*sum(x*(y-y_pred))
        bd=-(2/n)*sum((y-y_pred))
        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        plt.plot(x,y_pred,color='green')

# %%
x=df['math']

# %%
x
# Out:
# 0    92
# 1    56
# 2    88
# 3    70
# 4    80
# 5    49
# 6    65
# 7    35
# 8    66
# 9    67
# Name: math, dtype: int64

# %%
y=df['cs']

# %%
y
# Out:
# 0    98
# 1    68
# 2    81
# 3    80
# 4    83
# 5    52
# 6    66
# 7    30
# 8    68
# 9    73
# Name: cs, dtype: int64

# %%
print("hi")
